# %% [markdown]
# <a href="https://colab.research.google.com/github/vieduy/CS114.K21/blob/master/Kaggle_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e6779854-fc92-4710-adea-67df6380e40a" name="files[]" multiple disabled />
#      <output id="result-e6779854-fc92-4710-adea-67df6380e40a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"duyhoangvien","key":"be09bb42a19260054e0797f935de790f"}'}

# %%
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 68 Apr 10 08:16 kaggle.json

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# List available datasets.
# https://github.com/Kaggle/kaggle-api
# !kaggle datasets list -s covid
# Out:
# ...
# ref                                                            title                                                size  lastUpdated          downloadCount
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# sudalairajkumar/covid19-in-india                               COVID-19 in India                                    75KB  2020-04-10 06:22:53          12171
# kimjihoo/coronavirusdataset                                    Data Science for COVID-19 (DS4C)                      3MB  2020-04-07 15:09:23          26828
# allen-institute-for-ai/CORD-19-research-challenge              COVID-19 Open Research Dataset Challenge (CORD-19)    1GB  2020-04-03 22:53:52          46912
# roche-data-science-coalition/uncover                           UNCOVER COVID-19 Challenge                          123MB  2020-04-08 22:04:30           2197
# ...

# %%
# Copy the stackoverflow data set locally.
# !kaggle datasets download -d kimjihoo/coronavirusdataset
# Out:
# ...
#   0% 0.00/2.62M [00:00<?, ?B/s]
# 100% 2.62M/2.62M [00:00<00:00, 85.5MB/s]

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !unzip \*.zip
# Out:
# Archive:  coronavirusdataset.zip
#   inflating: Case.csv
#   inflating: PatientInfo.csv
#   inflating: PatientRoute.csv
#   inflating: Region.csv
#   inflating: SearchTrend.csv
#   inflating: SeoulFloating.csv
#   inflating: Time.csv
#   inflating: TimeAge.csv
#   inflating: TimeGender.csv
#   inflating: TimeProvince.csv
#   inflating: Weather.csv

# %%
import pandas as pd
d = pd.read_csv('Case.csv', encoding='utf-8')
d.head()
# Out:
#    case_id province           city  ...  confirmed   latitude   longitude
# 0  1000001    Seoul        Guro-gu  ...         98  37.508163  126.884387
# 1  1000002    Seoul  Dongdaemun-gu  ...         20  37.592888  127.056766
# 2  1000003    Seoul        Guro-gu  ...         40  37.481059  126.894343
# 3  1000004    Seoul   Eunpyeong-gu  ...         14   37.63369    126.9165
# 4  1000005    Seoul   Seongdong-gu  ...         13   37.55713    127.0403
#
# [5 rows x 8 columns]
